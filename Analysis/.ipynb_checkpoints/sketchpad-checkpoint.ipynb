# %%
import sys, os
script_directory = os.path.abspath('.')
print(script_directory)
sys.path.append(script_directory)
# Out:
# /home/admin/data/people/wyl/Transformer-SCBRIL/Analysis

# %%
# ref 这波是改工作目录，默认为ipynb文件所在目录
os.chdir(os.path.abspath('..'))
print(os.getcwd())
# Out:
# /home/admin/data/people/wyl/Transformer-SCBRIL

# %%
import trajFiner
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import trajFiner
#
# File ~/data/people/wyl/Transformer-SCBRIL/Analysis/trajFiner.py:6
#       4 from tqdm import tqdm
#       5 import numpy as np
# ----> 6 import folium
#       8 working_directory = os.getcwd()
#       9 working_directory = os.path.abspath('.')
#
# ModuleNotFoundError: No module named 'folium'

# %%
import importlib
importlib.reload(trajFiner)
# Out:
# <module 'trajFiner' from '/home/admin/data/people/wyl/Transformer-SCBRIL/Analysis/trajFiner.py'>

# %%
trajFiner.trajVisualize(who = 1102234, week_order = 3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c13427b409712915017b92f12dd34239 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c13427b409712915017b92f12dd34239&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c13427b409712915017b92f12dd34239 = L.map(
#                 &quot;map_c13427b409712915017b92f12dd34239&quot;,
#                 {
#                     center: [22.54, 114.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28febf735e3befcbacd70831e42b7a0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_28febf735e3befcbacd70831e42b7a0d.addTo(map_c13427b409712915017b92f12dd34239);
#
#
#             var poly_line_a4efb17d08d7929aa6e55d90dc22f4ca = L.polyline(
#                 [[114.04014587402344, 22.67372131347656], [114.05490801258355, 22.690258642671257]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_c13427b409712915017b92f12dd34239);
#
#
#             var marker_8a49d9bc213d7eef7b657560232b13f3 = L.marker(
#                 [114.04014587402344, 22.67372131347656],
#                 {}
#             ).addTo(map_c13427b409712915017b92f12dd34239);
#
#
#             var icon_87eb1c0642b6160e6b490a3b695d39ab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;play&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a49d9bc213d7eef7b657560232b13f3.setIcon(icon_87eb1c0642b6160e6b490a3b695d39ab);
#
#
#             var marker_17ba28a51c256a25c525d44ccbcb6c0b = L.marker(
#                 [114.05490801258355, 22.690258642671257],
#                 {}
#             ).addTo(map_c13427b409712915017b92f12dd34239);
#
#
#             var icon_02c6ce93c826342a8122923c15160884 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;stop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_17ba28a51c256a25c525d44ccbcb6c0b.setIcon(icon_02c6ce93c826342a8122923c15160884);
#
#
#             var poly_line_f1cc3c96926ce99d2a6b3884c7313321 = L.polyline(
#                 [[114.05490801258355, 22.690258642671257], [114.0314483642578, 22.653732299804688]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_c13427b409712915017b92f12dd34239);
#
#
#             var marker_fe14d40e88705e7cf58efa5f33e4a8fa = L.marker(
#                 [114.05490801258355, 22.690258642671257],
#                 {}
#             ).addTo(map_c13427b409712915017b92f12dd34239);
#
#
#             var icon_21e7eb676bedea4b5371178906d9a3a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;play&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe14d40e88705e7cf58efa5f33e4a8fa.setIcon(icon_21e7eb676bedea4b5371178906d9a3a2);
#
#
#             var marker_18f26364b9769e6cd98cd9001681a9dd = L.marker(
#                 [114.0314483642578, 22.653732299804688],
#                 {}
#             ).addTo(map_c13427b409712915017b92f12dd34239);
#
#
#             var icon_0f32efe3d84da85e503d3592ced03c4e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;stop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_18f26364b9769e6cd98cd9001681a9dd.setIcon(icon_0f32efe3d84da85e503d3592ced03c4e);
#
#
#             va
